# %%
from jobspy import scrape_jobs
import pandas as pd
from IPython.display import display, HTML

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

# %%
# example 1 (no hyperlinks, India)
jobs = scrape_jobs(
    site_name=["linkedin"],
    location='India',
    search_term="Cyber Security",
    results_wanted=5,
)
display(jobs)
# Out:
#        site                                              title  \
# 0  linkedin                 Information/Cyber Security Analyst
# 1  linkedin                                L2/Security Analyst
# 2  linkedin                                     Cyber Security
# 3  linkedin                 Chief Information Security Officer
# 4  linkedin  Urgent Hiring - IT Security Specialist (BFSI &...
#
#                                              company location date_posted  \
# 0                                             Zeotap           2023-06-30
# 1                                         SecurityHQ           2023-06-01
# 2  Dubai Jobs, Gulf Jobs, Jobs in Dubai, Qatar, K...           2023-08-28
# 3                                         Exafluence           2023-08-30
# 4  Dubai Jobs, Gulf Jobs, Jobs in Dubai, Qatar, K...           2023-09-07
#
#    job_type interval min_amount max_amount currency  \
# 0  fulltime   yearly       None       None     None
# 1  fulltime   yearly       None       None     None
# 2  fulltime   yearly       None       None     None
# 3  fulltime   yearly       None       None     None
# 4  fulltime   yearly       None       None     None
#
#                                          job_url  \
# 0  https://www.linkedin.com/jobs/view/3645817343
# 1  https://www.linkedin.com/jobs/view/3622912916
# 2  https://www.linkedin.com/jobs/view/3702097958
# 3  https://www.linkedin.com/jobs/view/3707284081
# 4  https://www.linkedin.com/jobs/view/3712029145
#
#                                          description
# 0  About The CompanyZeotap is the next-generation...
# 1  Job DescriptionWe are searching for a Security...
# 2  Resource Requirements by ProfileJob Responsibi...
# 3  Position : CISO (Chief Information Security Of...
# 4  Role: IT Security SpecialistDesignation: Manag...

# %%
# example 2 - remote India & hyperlinks
jobs = scrape_jobs(
    site_name=["linkedin", "indeed"],
    search_term="software engineer",
    country_indeed="India",
    hyperlinks=True,
    is_remote=True,
    results_wanted=5, 
)
display(jobs)
# Out:
#        site                                  title  \
# 0    indeed                      Software Engineer
# 1    indeed                      Software Engineer
# 2    indeed                      Software Engineer
# 3    indeed                      Software Engineer
# 4    indeed                    Front End Developer
# 5  linkedin  Software Engineer Internship (Remote)
# 6  linkedin                      Software Engineer
# 7  linkedin             Software Engineer (Remote)
# 8  linkedin             Software Engineer (Remote)
# 9  linkedin     JavaScript Developer (Entry Level)
#
#                                              company           location  \
# 0                                             seikor      Remote, India
# 1                                          Microsoft   Noida, UP, India
# 2                                              A.R.S   Delhi, DL, India
# 3                                   Global Employees      Remote, India
# 4                                           BigShyft      Remote, India
# 5                                     The Home Depot        Atlanta, GA
# 6                                         Fieldguide  San Francisco, CA
# 7                                     The Home Depot        Atlanta, GA
# 8                                     The Home Depot        Atlanta, GA
# 9  Pattern Learning AI - Career & Tech Recruitmen...       New York, NY
#
#   date_posted  job_type interval min_amount max_amount currency  \
# 0  2023-09-05  parttime  monthly         -1      30000      INR
# 1  2023-09-26  fulltime     None       None       None     None
# 2  2023-09-08  fulltime   yearly    1200000    1000000      INR
# 3  2023-09-01  fulltime   yearly    3000000    1200000      INR
# 4  2023-09-26      None   yearly    1200000     800000      INR
# 5  2023-09-09  fulltime   yearly       None       None     None
# 6  2023-08-16  fulltime   yearly       None       None     None
# 7  2023-09-14  fulltime   yearly       None       None     None
# 8  2023-09-19  fulltime   yearly       None       None     None
# 9        None  fulltime   yearly       None       None     None
#
#                                        job_url_hyper  \
# 0  <a href="https://in.indeed.com/viewjob?jk=41ed...
# 1  <a href="https://in.indeed.com/viewjob?jk=c4aa...
# 2  <a href="https://in.indeed.com/viewjob?jk=7f2f...
# 3  <a href="https://in.indeed.com/viewjob?jk=6485...
# 4  <a href="https://in.indeed.com/viewjob?jk=3daa...
# 5  <a href="https://www.linkedin.com/jobs/view/37...
# 6  <a href="https://www.linkedin.com/jobs/view/36...
# 7  <a href="https://www.linkedin.com/jobs/view/37...
# 8  <a href="https://www.linkedin.com/jobs/view/37...
# 9  <a href="https://www.linkedin.com/jobs/view/37...
#
#                                          description
# 0  Location - Remote (anywhere in india) Work hou...
# 1  Web Experiences and Services Team – Senior Sof...
# 2  Designation: Software Development Engineer Loc...
# 3  Permanent WFH Position- Software Engineer Time...
# 4  What you will do :- Integration of user-facing...
# 5  Internship OverviewThe Home Depot's Summer Int...
# 6  About us:Fieldguide is establishing a new stat...
# 7  Position PurposeThe Software Engineer is respo...
# 8  Position PurposeThe Software Engineer is respo...
# 9  JavaScript Developer (Entry Level) - US/Canada...

# %%
# example 3 - with hyperlinks, india - linkedin with easy apply
jobs = scrape_jobs(
    site_name=["linkedin"],
    location='India',
    search_term="engineer",
    hyperlinks=True,
    results_wanted=5,
    easy_apply=True
)
display(jobs)
# Out:
#        site                                              title  \
# 0  linkedin                                   Chassis Steering
# 1  linkedin                                Production Engineer
# 2  linkedin  Mechanical Maintenance Engineer  - Chakan Pune...
# 3  linkedin                             Environmental Engineer
# 4  linkedin                             Environmental Engineer
#
#                                    company location date_posted  job_type  \
# 0                        Tata Technologies           2023-06-01  fulltime
# 1               Envirotech Systems Limited           2023-09-17  fulltime
# 2                                  CIEL HR           2023-08-31  fulltime
# 3  Samsung C&T, Engineering & Construction           2023-09-18  fulltime
# 4  Samsung C&T, Engineering & Construction           2023-09-18  fulltime
#
#   interval min_amount max_amount currency  \
# 0   yearly       None       None     None
# 1   yearly       None       None     None
# 2   yearly       None       None     None
# 3   yearly       None       None     None
# 4   yearly       None       None     None
#
#                                        job_url_hyper  \
# 0  <a href="https://www.linkedin.com/jobs/view/35...
# 1  <a href="https://www.linkedin.com/jobs/view/37...
# 2  <a href="https://www.linkedin.com/jobs/view/37...
# 3  <a href="https://www.linkedin.com/jobs/view/37...
# 4  <a href="https://www.linkedin.com/jobs/view/37...
#
#                                          description
# 0  Designation: Design EngineerTotal Exp: 2 - 6 Y...
# 1  About Envirotech System LimitedEnvirotech Syst...
# 2  Co-coordinating with shift supervisor to reduc...
# 3  Position: Environmental Engineer- Power/Desali...
# 4  Position: Environmental Engineer- Power/Desali...
